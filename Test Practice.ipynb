# %%
import requests
from bs4 import BeautifulSoup

page = requests.get("https://bankofmaharashtra.in/personal-banking/loans/home-loan")
soup = BeautifulSoup(page.content, 'html.parser')
# Extract title of page
page_title = soup.title

# Extract body of page
page_body = soup.body

# Extract head of page
page_head = soup.head

# print the result
print(page_title, page_head)
# Out:
# <title>Bank of Maharashtra - Home Loan with Lowest Interest Rates</title> <head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="no-cache, must-revalidate, post-check=0, pre-check=0" http-equiv="cache-control"/><title>Bank of Maharashtra - Home Loan with Lowest Interest Rates</title><meta content="With Bank of Maharashtra, you can get home loans for flat, plot purchase, construction or renovation with the lowest ROI at 7.35%. Know your eligibility today. " name="Description"/><meta content="Bank of Maharashtra" name="keywords"/><link href="//bankofmaharashtra.in/personal-banking/loans/home-loan" hreflang="en-in" rel="altenate"/><link href="//bankofmaharashtra.in/hi/personal-banking/loans/home-loan" hreflang="hi-in" rel="altenate"/><link href="//bankofmaharashtra.in/mar/personal-banking/loans/home-loan" hreflang="mr-in" rel="altenate"/><link href="//bankofmaharashtra.in/personal-banking/loans/home-loan" hreflang="x-default" rel="altenate"/><link href="https://bankofmaharashtra.in/personal-banking/loans/home-loan" rel="canonical"/><meta content="With Bank of Maharashtra, you can get home loans for flat, plot purchase, construction or renovation with the lowest ROI at 7.35%. Know your eligibility today." name="abstract"/><meta content="Bank Of Maharashtra,India's leading Public sector Bank" name="author"/><meta content="Bank Of Maharashtra" name="copyright"/><meta content="no-cache" name="cache-control"/><meta content="Global" name="distribution"/><meta content="Global" name="document-distribution"/><meta content="General" name="document-rating"/><meta content="Public" name="document-rights"/><meta content="static" name="document-state"/><meta content="Bank Of Maharashtra, India's leading Public sector Bank" name="publisher"/><meta content="General" name="rating"/><meta content="never" name="expires"/><meta content="General" name="resource-type"/><meta content="https://bankofmaharashtra.in/" name="Address"/><meta content="INDEX,FOLLOW" name="robots"/><meta content="Bank of Maharashtra - Home Loan with Lowest Interest Rates" property="og:title"/><meta content="https://bankofmaharashtra.in/personal-banking/loans/home-loan" property="og:url"/><meta content="With Bank of Maharashtra, you can get home loans for flat, plot purchase, construction or renovation with the lowest ROI at 7.35%. Know your eligibility today." property="og:description"/><meta content="website" property="og:type"/><meta content="https://bankofmaharashtra.in/projectfiles/bomlayoutcontainer/default/images/ogimage/ogimage.jpg" property="og:image"/><meta content="https://bankofmaharashtra.in/projectfiles/bomlayoutcontainer/default/images/ogimage/ogimage.jpg" property="og:image"/><meta content="Bank of Maharashtra" property="og:site_name"/><meta content="Shivajinagar" property="og:street-address"/><meta content="Lokmangal" property="og:locality"/><meta content="Pune" property="og:region"/><meta content="India" property="og:country-name"/><meta content="cmcustomerservice@mahabank.co.in" property="og:email"/><meta content="18002334526" property="og:phone_number"/><meta content="summary_large_image" property="twitter:card"/><meta content="https://bankofmaharashtra.in/personal-banking/loans/home-loan" property="twitter:url"/><meta content="Bank of Maharashtra - Home Loan with Lowest Interest Rates" property="twitter:title"/><meta content="With Bank of Maharashtra, you can get home loans for flat, plot purchase, construction or renovation with the lowest ROI at 7.35%. Know your eligibility today." property="twitter:description"/><meta content="https://bankofmaharashtra.in/projectfiles/bomlayoutcontainer/default/images/ogimage/ogimage.jpg" property="twitter:image"/><script nonce="FSBwwDG480WlsNU18kTc/A==">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='d ...
# else if(userAgentString.indexOf("MSIE")>-1||userAgentString.indexOf("rv:")>-1)
# {return true;}
# else{return false;}}</script><script nonce="FSBwwDG480WlsNU18kTc/A==" type="application/ld+json">
#     {"@context": "https://schema.org","@type": "Organization","name": "Bank of Maharashtra","url": "https://bankofmaharashtra.in/","logo": "https://bankofmaharashtra.in/projectfiles/bomlayoutcontainer/default/images/logo/logo-white.svg","sameAs": ["https://facebook.com/mahabank","https://twitter.com/mahabank","https://instagram.com/mahabank/","https://youtube.com/channel/UCevaMPXN3n3aHZqbBl4sdVA","https://inkedin.com/company/mahabank","https://pinterest.com/mahabank/"]}
#     </script><script nonce="FSBwwDG480WlsNU18kTc/A==" type="application/ld+json">
#     {"@context": "http://schema.org","@type": "WebSite","name": "Bank of Maharashtra","url": "https://bankofmaharashtra.in/","description": "Official website of Bank of Maharashtra.","potentialAction": {"@type": "SearchAction","target": "https://bankofmaharashtra.in/search?q={search_term_string}","query-input": "required name=search_term_string"},"hasPart": [{"@type": "WebPage","name": "Home Loan","url": "https://bankofmaharashtra.in/personal-banking/loans/home-loan","description": "Explore our home loan offerings for personal banking customers.","mainEntityOfPage": "https://bankofmaharashtra.in/personal-banking/loans/home-loan"},{"@type": "WebPage","name": "Open your Account through Video-KYC","url": "https://bankofmaharashtra.in/vcip","description": "Experience the convenience of opening your account through Video-KYC.","mainEntityOfPage": "https://bankofmaharashtra.in/vcip"},{"@type": "WebPage","name": "Mobile Banking", "url": "https://bankofmaharashtra.in/maha-mobile","description": "Discover the features and benefits of our mobile banking services.","mainEntityOfPage": "https://bankofmaharashtra.in/maha-mobile"},{"@type": "WebPage","name": "WhatsApp Banking","url": "https://bankofmaharashtra.in/whatsapp-banking","description": "Explore banking services through WhatsApp for seamless communication.","mainEntityOfPage": "https://bankofmaharashtra.in/whatsapp-banking"},{"@type": "WebPage", "name": "Careers","url": "https://bankofmaharashtra.in/current-openings","description": "Explore career opportunities at Bank of Maharashtra.","mainEntityOfPage": "https://bankofmaharashtra.in/current-openings"}]}
#     </script><script nonce="FSBwwDG480WlsNU18kTc/A==" type="application/ld+json">
#     {"@context":"http://schema.org", "@type":"FinancialProduct","name":"Maha Super Housing Loan Scheme","url":"https://bankofmaharashtra.in/personal-banking/loans/home-loan","mainEntityOfPage":{    "@type":"WebPage","@id":"https://bankofmaharashtra.in/personal-banking/loans/home-loan"},"broker":{    "@type":"Organization","name":"Bank of Maharashtra","url":"https://bankofmaharashtra.in/","logo":"https://bankofmaharashtra.in/projectfiles/bomlayoutcontainer/default/images/logo/logo-white.svg"},"description":"With Bank of Maharashtra, you can get home loans for flat, plot purchase, construction or renovation with the lowest ROI at 7.35%. Know your eligibility today.","category":"Home Loan"}
#     </script><script nonce="FSBwwDG480WlsNU18kTc/A==" type="application/ld+json">
#     {"@context": "https://schema.org","@type": "FAQPage","mainEntity": [{"@type": "Question","name": "What is a Home loan and how does it work?","acceptedAnswer": {"@type": "Answer","text": "Home loans are availed for1. Construction/acquiring of new or existing house/flat and extension of existing house/flat.2. Purchase of plot and construction there on.3. For Repairs /renovation/alternation of existing house/flat for new standalone borrowers.A Bank of Maharashtra home loan provides numerous benefits such as facility to apply online, quick loan processing, attractive interest rates, customized repayment options and simple & hassle-free documentation."}},{"@type": "Question","name": "What are features of Home loan?","acceptedAnswer": {"@type": "Answer","text": "1. 0.05% concession to women and defence personal.2. Maximum tenure up to 30 years/up to 75 years of age.3. No Pre-payment/Pre-closure/Part payment charges.4. Concession in ROI for Housing Loan borrower in Car Loan and Education loan.5. Bank of Maharashtra Offers Lowest Interest Rate on Home Loan in India. "}},{"@type": "Question","name": "How will Bank of Maharashtra decide the home loan amount i am eligible for?","acceptedAnswer": {"@type": "Answer","text": "Maximum loan amount will be lowest of loan amount assessed on the basis of Permissible Deduction norms, Maximum permissible LTV ratio, Loan amount requested."}},{"@type": "Question","name": "When does my home loan EMIs start?","acceptedAnswer": {"@type": "Answer","text": "EMI's begins from the month subsequent to the month in which disbursement of the loan is done. For loans for under-construction properties EMI usually begins after the complete home loan is disbursed but customers can choose to begin their emi’s as soon as they avail their first disbursement and their emi’s will increase proportionately with every subsequent disbursement. For resale cases, since the whole loan amount is disbursed in one go, emi on the whole loan amount start from the subsequent to the month of disbursement"}},{"@type": "Question","name": "Can home loan be transferred from one bank to another?","acceptedAnswer": {"@type": "Answer","text": "Yes, it is possible to transfer a home loan in India, from one Bank to another under certain circumstances. Home loan transfer typically refers to the process of transferring an existing home loan from one bank or financial institution to another.This is done to take advantage of better interest rates, lower fees or improved loan terms offered by the new lender"}},{"@type": "Question","name": "What is floating interest rate?","acceptedAnswer": {"@type": "Answer","text": "A floating interest rate sometimes known as variable interest rate, is an interest rate that varies over time according to changes in a reference rate or index.It's often used in financial products like mortgages, home loans and other investments."}},{"@type": "Question","name": "What is the EMI for 50 lakhs home loan?","acceptedAnswer": {"@type": "Answer","text": "For calculating the EMI (Equated Monthly Installment) for a home loan in India, we must also consider the loan amount, interest rate and loan period.To get accurate EMI estimate, visit the website of Bank of Maharashtra & calculate the precise EMI cost using home loan EMI calculator.The approximate EMI for a 50 lakhs home loan with an interest rate of 8.50% per annum and 15 year tenure would be around ₹49237 "}},{"@type": "Question","name": "What are the different type of home loan available?","acceptedAnswer": {"@type": "Answer","text": "Depending upon the needs and requirements of customers, there are different types of home loans available in India.Some of the popular types of home loans includes,1. Plot Purchase& Construction thereon Loans2. Home/Flat Purchase Loans3. Loans for repair/renovation of existing homes4. Home Extension Loan5. NRI Home LoansBank of Maharashtra provides varieties of home loans under Maha Super Housing Loan Scheme. "}},{"@type": "Question", ...
#     </script><script nonce="FSBwwDG480WlsNU18kTc/A==" type="application/ld+json">
#     {"@context": "https://schema.org/","@type": "BreadcrumbList","itemListElement": [{"@type": "ListItem","position": 1,"name": "Home","item": "https://bankofmaharashtra.in/"},{"@type": "ListItem","position": 2,"name": "Personal Banking","item": "https://bankofmaharashtra.in/personal-products"},{"@type": "ListItem","position": 3,"name": "Loans","item": "https://bankofmaharashtra.in/retail-loans"},{"@type": "ListItem","position": 4,"name": "Home Loan","item": "https://bankofmaharashtra.in/personal-banking/loans/home-loan"}]}
#     </script><script nonce="FSBwwDG480WlsNU18kTc/A==" type="application/ld+json">
#     {"@context": "http://schema.org","@type": "LoanOrCredit","name": "Home Loan","brand":"Bank of Maharashtra","description": "Borrow instant home loan online with minimal documentation from Bank of Maharashtra.Apply for a home loan upto 90 percentage at attractive interest rates, quick disbursal and low EMIs.","image":"https://bankofmaharashtra.in/projectfiles/bomlayoutcontainer/default/images/logo/logo.svg"}
#     </script><body class="english" oncontextmenu="return false"><noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-WT4GMP3" style="display:none;visibility:hidden" width="0"></iframe></noscript><input id="hdnUrl" type="hidden" value="/personal-banking/loans/home-loan"/> <input id="hdnbaseUrl" type="hidden" value="https://bankofmaharashtra.in/"/><div class="dvAudioBtn"><button aria-label="Play website content" class="btn-audio" id="audioplay" tabindex="0"> <i class="fa fa-volume-up fa-lg"></i> </button> <button aria-label="Pause website content" class="btn-audio" id="audiopause" style="display:none" tabindex="0"> <i class="fa fa-pause fa-lg"></i> </button></div><div class="outerWrap"><header><div class="tophead"><div class="container-fluid cmpad d-flex"><div class="col-10 topleft p-0"><ul aria-label="Main navigation" class="nav" role="navigation"><li class="active"><a href="/" tabindex="0">Home</a><li><a href="/about-us" tabindex="0">About Us</a><li><a aria-label="Locate Us (opens in a new window)" href="//app.mapmyindia.com/bom/" tabindex="0" target="_blank"> Locate Us </a><li><a href="/careers" tabindex="0">Careers</a><li><a href="/contact-us" tabindex="0">Contact Us</a><li class="search-container d-none d-lg-block"><form action="/search" id="frmSearch" method="get"><div class="searchcol"><input aria-label="Search" class="form-control" id="txtSearchText" name="q" placeholder="Type here to search..." tabindex="0" type="search"/> <button aria-label="search" class="btn btnsubmit" id="btnSearch" tabindex="0" type="submit"><span class="mglass">⚲</span></button></div></form></li></li></li></li></li></li></ul></div><div class="col topright px-0"><ul class="fontsize"><li><button aria-label="skip to content" id="skipToContent" tabindex="0" type="button"> Skip to Content </button></li></ul><div class="btn-group language"><button aria-expanded="false" aria-haspopup="true" class="btn btn-outline-secondary btn-sm dropdown-toggle" data-toggle="dropdown" id="btnLang" tabindex="0" type="button">English</button><div class="dropdown-menu dropdown-menu-right"><a aria-label="हिन्दी" class="dropdown-item" href="/hi/personal-banking/loans/home-loan" tabindex="0">हिन्दी</a><a aria-label="मराठी" class="dropdown-item" href="/mar/personal-banking/loans/home-loan" tabindex="0">मराठी</a></div></div><div class="accesibility-btn"><button class="accesbtn" href="#0" id="accessBtn" tabindex="0" type="button"> <img alt="Accessibilty" src="/projectfiles/bomlayoutcontainer/default/images/icons/acesss.svg"/> </button></div></div></div></div><div class="clear"></div><div class="clear"></div><div class="container-fluid d-flex cmpad"><div class="col-8 col-lg-3 logo p-0"><a href="/" tabindex="0"> <img alt="Bank of Maharashtra" class="logoimg logowhite" src="/projectfiles/bomlayoutcontainer/default/images/logo/logo-white.svg" title="Bank of Maharashtra"/> </a></div><div class="col-lg-9 col-4 p-0"><div class="d-block d-lg-none float-right"><div class="d-flex align-items-center"><div class="search-main"><button aria-label="Search" class="search" tabindex="0" title="Search"> <i class="fa fa-search fa-lg" style="color:#ffffff"></i> </button></div><div><a class="menubtn cd-dropdown-trigger" href="#0" tabindex="0"><span class="fa fa-align-right"></span> <span class="txt">Menu</span></a></div></div></div><div aria-label="Main Menu navigation" class="navbar d-none d-lg-flex" role="navigation"><div class="megamenu" id="personal"><a aria-controls="megamenu-content-1" aria-expanded="false" class="mainli" href="/personal-products" tabindex="0"> Personal </a><div class="megamenu-content" id="megamenu-content-1"><div class="container-fluid"><div class="row"><div class="tabmenucol"><div aria-orientation="vertical" class="nav flex-column nav-pills custscrollA" id="personalNav" role="tablist"><a aria-controls="pbCurDeposit" aria-selected="false" class="nav-link active" data-toggle="pill" href="#pbCurDeposit" id="pbCDeposit" role="tab" tabindex="0"> Deposits </ ...
# else{$('.homesocial').fadeIn();}});</script><script nonce="FSBwwDG480WlsNU18kTc/A==">var proswiper=new Swiper('.swiper-products',{lazy:true,loop:true,spaceBetween:15,slidesPerView:1,observer:true,observeParents:true,pagination:{el:'.products-pagination',clickable:true,},navigation:{nextEl:'.products-next',prevEl:'.products-prev',},disableOnInteraction:true,speed:400,autoplay:{delay:2000,},a11y:{enabled:true,slideLabelMessage:'{{index}} / {{slidesLength}}',prevSlideMessage:'Previous slide',nextSlideMessage:'Next slide',},});proswiper.on('slideChange',()=>{const currentSlide=proswiper.activeIndex+1;const totalSlides=proswiper.slides.length;document.querySelectorAll('.swiper-products .swiper-slide').forEach((slide,index)=>{slide.setAttribute('aria-label',`Slide ${index + 1} of ${totalSlides}`);});document.querySelector('.swiper-products .swiper-slide-active').setAttribute('aria-current','true');});$('.swiper-products').mouseenter(function(){proswiper.autoplay.stop();});$('.swiper-products').mouseleave(function(){proswiper.autoplay.start();});$('.notice-play-stop').on('click',function(){if($(this).data('txt')=='Pause'){proswiper.autoplay.stop();$(this).data('txt','Play');$('.notice-play-stop').removeClass("fa-pause").addClass("fa-play");}else{proswiper.autoplay.start();$(this).data('txt','Pause');$('.notice-play-stop').removeClass("fa-play").addClass("fa-pause");}});</script><script nonce="FSBwwDG480WlsNU18kTc/A==">var swiper=new Swiper('.similarslidenri',{pagination:{el:'.similarslidenri-pagination',clickable:true,},breakpoints:{0:{slidesPerView:1,spaceBetween:10,},500:{slidesPerView:2,},768:{slidesPerView:3,},1180:{slidesPerView:3,spaceBetween:15,},}});</script><script nonce="FSBwwDG480WlsNU18kTc/A==">$(document).ready(function(){$('.lazyloadimg').each(function(){var imageDataSource=$(this).data('src');var setImageSource=$(this).attr('src',imageDataSource);});var prvTitle=localStorage.getItem("PrvT");var prvUrl=localStorage.getItem("PrvU");var CTitle=localStorage.getItem("CurT");var CUrl=localStorage.getItem("CurU");var curUrl=window.location.href;var curTitle=document.title;var referrer=document.referrer;var origin=window.location.origin;if(prvUrl!=null){$("#prvUrl").val(prvUrl);localStorage.setItem("PrvT",curTitle);localStorage.setItem("PrvU",curUrl);}
# else{$("#prvUrl").val("https://bankofmaharashtra.in");localStorage.setItem("PrvT",curTitle);localStorage.setItem("PrvU",curUrl);}});function RedirectToPrv(){var prvUrl=$("#prvUrl").val();if(prvUrl!=""){window.location=prvUrl;}}
# $("#myHref").on('click',function(){var prvUrl=$("#prvUrl").val();if(prvUrl!=""){window.location=prvUrl;}});var hash=document.location.hash;var prefix="tab_";if(hash){$('.nav-tabs a[href="'+hash.replace(prefix,"")+'"]').tab('show');$('html, body').animate({scrollTop:$("#divBannerHead").offset().top},500);}
# $('.nav-tabs a').on('shown',function(e){window.location.hash=e.target.hash.replace("#","#"+prefix);});</script><script nonce="FSBwwDG480WlsNU18kTc/A==" src="/projectfiles/bomlayoutcontainer/default/js/maincal.js?v=527202594934"></script><script nonce="FSBwwDG480WlsNU18kTc/A==" src="/projectfiles/bomlayoutcontainer/default/js/echarts-en.min.js?v=2152023103330"></script><script nonce="FSBwwDG480WlsNU18kTc/A==" src="/projectfiles/bomlayoutcontainer/default/js/piechart.js?v=517202512448"></script><script nonce="FSBwwDG480WlsNU18kTc/A==">$(function(){fn_InsertVisitorCounter('1','3');fn_GETVisitorCounter('1','3');if($("#emibtn").length>0){$("#text_box_name_emi").val("100000");$("#text_box_name1_emi").val("7.35");$("#text_box_name_emi").trigger("input");$("#text_box_name1_emi").trigger("input");$("#text_box_name2_emi").trigger("input");$("#emibtn").trigger("click");}});var swiper=new Swiper('.similarslide',{pagination:{el:'.similarslide-pagination',clickable:true,},breakpoints:{0:{slidesPerView:1,spaceBetween:10,},500:{slidesPerView:2,},768:{slidesPerView:3,},1180:{slidesPerView:4,spaceBetween:15,},}});</script><script nonce="FSBwwDG480WlsNU18kTc/A==">document.querySelector('.search').addEventListener('click',function(){const searchBox=document.querySelector('.search-box');if(searchBox.style.display==='none'||searchBox.style.display===''){searchBox.style.display='block';}else{searchBox.style.display='none';}});</script><script nonce="FSBwwDG480WlsNU18kTc/A==">function LoadImg(){const targets=document.querySelectorAll("img.loadimg");const lazyLoad=(target)=>{const io=new IntersectionObserver((entries,observer)=>{entries.forEach(entry=>{if(entry.isIntersecting){const img=entry.target;const src=img.getAttribute("data-src");if(src!=null){img.setAttribute("src",src);img.classList.add("fade");observer.disconnect();}
# const src1=img.getAttribute("data-isrc");if(src1!=null){img.setAttribute("src",src1);img.classList.add("fade");observer.disconnect();}}})},{threshold:[0.5]});io.observe(target);}
# targets.forEach(lazyLoad);}
# LoadImg();function removeItemOnce(arr,value){if(arr!=null&&arr.length>0){var index=arr.indexOf(value);if(index>-1){arr.splice(index,1);}}
# return arr;}
# var LikeArray=[];$(document).ready(function(){LikeArray=JSON.parse(localStorage.getItem("likearray")||"[]");if(LikeArray.length>0){if($("#heartb").length){var bid=$("#heartb").data('id');var index=jQuery.inArray(bid.toString(),LikeArray).toString();if(index=='-1'){$("#heartb").removeClass("fa fa-heart");$("#heartb").addClass("far fa-heart");$("#heartb").data('like','no');}
# else{$("#heartb").removeClass("far fa-heart");$("#heartb").addClass("fa fa-heart");$("#heartb").data('like','yes');}}
# else{$("#heartb").removeClass("far fa-heart");$("#heartb").addClass("fa fa-heart");$("#heartb").data('like','yes');}}
# $("body #btnSend").click(function(e){fn_BlogCommentSave();});$("body .splike").click(function(e){fn_BlogLike(this);});$("body .blog-cmnt").click(function(e){fn_BlogComment(this);});$("body .bcmnt-close").click(function(e){fn_BgMdalClose();});$("body #refCaptchaBtn").click(function(e){fn_RefreshCapB();});$("body #btnBReset").click(function(e){fn_FresetB();});});function fn_BlogCommentSave(){if($("#txtComment").val()!=""){$("#btnSend").hide();$("#btnSending").show();var token=$('input[name="__RequestVerificationToken"]').val();var headers={};headers['__RequestVerificationToken']=token;var jsonDet={BlogId:$("#blogId").val(),Comment:$("#txtComment").val(),};$.ajax({url:'/blogs/addblogcomments',type:"POST",dataType:"JSON",data:jsonDet,headers:headers,success:function(data){$("#txtComment").val('');$("#btnSend").show();$("#btnSending").hide();window.setTimeout(function(){$('#commentmodal').animate({left:'0',opacity:"hide"});},3000);}});}}
# function fn_RefreshCapB(){d=new Date();$("#capImgB").attr("src","/captcha/getcaptchaimage?"+d.getTime());}
# $('body').on('click','#btnBcSend',function(e){e.preventDefault();if(fn_ValidateBlogComment()){if($("#Name").val()!=""&&$("#txtComment").val()!=""&&$("#Email").val()!=""&&$("#Captcha").val()!=""){$("#btnBcSend").hide();$("#btnBcSending").show();var token=$('input[name="__RequestVerificationToken"]').val();var headers={};headers['__RequestVerificationToken']=token;var jsonDet={BlogId:$("#blogId").val(),Comment:$("#txtComment").val(),Name:$("#Name").val(),EmailId:$("#Email").val(),Captcha:$("#Captcha").val()};$.ajax({url:'/blogs/addblogcomments',type:"POST",dataType:"JSON",data:jsonDet,headers:headers,success:function(data){if(data.Msg=="success"){fn_FresetB();fn_RefreshCapB();$('#errmsg #ivmsg').text("Comment Added Successfully.....");$('#errmsg #ivmsg').attr("style","color:#304817;");$('#errmsg').attr("style","background-color:#bfddbd;");$('#errmsg').show();setTimeout(function(){$('#errmsg #ivmsg').text("");$('#errmsg #ivmsg').attr("style","color:#a50312");$('#errmsg').attr("style","background-color:#f5cbcf;");$('#errmsg').hide();$("#commentmodal").hide();},7000);}
# else if(data.Msg=="captchaerror"){$('#dvvcmsg #vcmsg').text("Invalid Captcha");$("#Captcha").removeClass("txt-error");$("#btnBcSending").hide();$("#btnBcSend").show();}
# else if(data.Msg=="invalidcontenterror"){$('#errmsg #ivmsg').text("Invalid Content");$("#btnBcSending").hide();$("#btnBcSend").show();}
# else{$('#errmsg #ivmsg').text("Some errors occured.. Please try again");$("#btnBcSending").hide();$("#btnBcSend").show();}}});}}});function fn_ValidateBlogComment(){var stat=true;$('#dvnamemsg #namemsg').text('');$("#Name").removeClass("txt-error");$('#dvemsg #emsg').text('');$("#Email").removeClass("txt-error");$('#dvcommentmsg #commentmsg').text("");$("#txtComment").removeClass("txt-error");$('#dvvcmsg #vcmsg').text("");$("#Captcha").removeClass("txt-error");if($("#Name").val()==""){$('#dvnamemsg #namemsg').text('Enter name');$("#Name").addClass("txt-error");stat=false;}
# if($("#Email").val()!=""){var emailReg=/^([\w-\.]+@([\w-]+\.)+[\w-]{2,4})?$/;if(!emailReg.test($("#Email").val())){$('#dvemsg #emsg').text("Enter valid Email-Id");$("#Email").addClass("txt-error");stat=false;}}
# else{$('#dvemsg #emsg').text("Enter Email-Id");$("#Email").addClass("txt-error");stat=false;}
# if($("#txtComment").val()==""){$('#dvcommentmsg #commentmsg').text('Enter Comment');$("#txtComment").addClass("txt-error");stat=false;}
# if($("#Captcha").val()==""){$('#dvvcmsg #vcmsg').text("Enter captcha");$("#Captcha").addClass("txt-error");stat=false;}
# return stat;}
# function fn_FresetB(){$("#Name").val('');$("#txtComment").val('');$("#Email").val('');$("#Captcha").val('');$('#dvnamemsg #namemsg').text('');$('#dvcommentmsg #commentmsg').text('');$('#dvemsg #emsg').text('');$('#dvvcmsg #vcmsg').text('');$("#btnBcSend").show();$("#btnBcSending").hide();fn_RefreshCapB();}
# function fn_BlogLikeFromPage(blgid){LikeArray=JSON.parse(localStorage.getItem("likearray")||"[]");var token=$('input[name="__RequestVerificationToken"]').val();var headers={};headers['__RequestVerificationToken']=token;var jsonDet={BlogId:blgid,};$.ajax({url:'/blogs/addbloglikes',type:"POST",dataType:"JSON",data:jsonDet,headers:headers,success:function(data){var liket=$("#heartb").data('like');if(liket=='yes'){$("#heartb").removeClass("fa fa-heart");$("#heartb").addClass("far fa-heart");$("#heartb").data('like','no');LikeArray=removeItemOnce(LikeArray,blgid.toString());}
# else{$("#heartb").removeClass("far fa-heart");$("#heartb").addClass("fa fa-heart");$("#heartb").data('like','yes');LikeArray[LikeArray.length]=blgid.toString();}
# localStorage.setItem("likearray",JSON.stringify(LikeArray));}});}
# function fn_ToCommentSec(){$('html, body').animate({scrollTop:$("#test").offset().top},2000);}
# if($('.share-button-b').length){const shareButtonb=document.querySelector('.share-button-b');shareButtonb.addEventListener('click',event=>{var bu=$("#hdnUrl").val();var bub=$("#hdnbaseUrl").val();bub=bub.endsWith('/')?bub.slice(0,-1):bub;bub=bub+bu;if(navigator.share){navigator.share({title:$("#Btitle").text(),url:bub}).then(()=>{}).catch(console.error);}else{shareDialog.classList.add('is-open');}});}
# const shareDialog=document.querySelector('.share-dialog');$('body').on('click','a',function(e){var ahref=$(this).attr('href');var atarget=$(this).prop('target');if(atarget==''){atarget="_self";}
# var u_campaign='';var u_medium='';var u_source=''
# if(u_campaign!=''){if(ahref.indexOf("digileads.bankofmaharashtra.in")!=-1){if(ahref.indexOf("?")!=-1){e.preventDefault();window.open(ahref+(u_campaign?"&sec="+u_campaign:"")+("&utm_source="+u_source+"&utm_medium="+u_medium+"&utm_campaign="+u_campaign),atarget);}
# else{e.preventDefault();window.open(ahref+(u_campaign?"?bom&sec="+u_campaign:"")+("&utm_source="+u_source+"&utm_medium="+u_medium+"&utm_campaign="+u_campaign),atarget);}}
# else{if(ahref.indexOf("?")!=-1){e.preventDefault();window.open(ahref+("&utm_source="+u_source+"&utm_medium="+u_medium+"&utm_campaign="+u_campaign),atarget);}
# else{e.preventDefault();window.open(ahref+("?utm_source="+u_source+"&utm_medium="+u_medium+"&utm_campaign="+u_campaign),atarget);}}}});</script><script nonce="FSBwwDG480WlsNU18kTc/A==">function fnRemoveCookieWarning(){if(fnReadCookie("cook-parent")=="1"){glblFnRemoveElementsByClass("cook-parent");}
# else{$(".cook-parent").show();}}
# fnRemoveCookieWarning();function fnCreateCookie(cookiname,cookivalue,timeinminutes){var d=new Date();d.setTime(d.getTime()+(timeinminutes*60*1000));var expires="expires="+d.toGMTString();document.cookie=cookiname+"="+cookivalue+";"+expires+";path=/";}
# function fnReadCookie(cookiname){var name=cookiname+"=";var decodedCookie=decodeURIComponent(document.cookie);var ca=decodedCookie.split(';');for(var i=0;i<ca.length;i++){var c=ca[i];while(c.charAt(0)==' '){c=c.substring(1);}
# if(c.indexOf(name)==0){return c.substring(name.length,c.length);}}
# return"";}
# function glblFnRemoveElementsByClass(className){const elements=document.getElementsByClassName(className);while(elements.length>0){elements[0].parentNode.removeChild(elements[0]);}}
# function fnDeleteCookie(cookiname){var d=new Date();d.setDate(d.getDate()-1);var expires=";expires="+d;var value="";document.cookie=cookiname+"="+value+expires+"; path=/";}
# $('body').on('click','.cook-readmore',function(e){$(".cook-readmore").hide();$(".cook-mob").show();});if($(".btn-cook-x").length>0){$('body').on('click','.btn-cook-x',function(e){fnCreateCookie("cook-parent","1",525600);fnRemoveCookieWarning();});}
# if($(".cook-c2").length>0){$('body').on('click','.btn-cook',function(e){fnCreateCookie("cook-parent","1",525600);fnRemoveCookieWarning();});}</script><script nonce="FSBwwDG480WlsNU18kTc/A==" src="/projectfiles/bomlayoutcontainer/default/js/articulate.min.js"></script><script nonce="FSBwwDG480WlsNU18kTc/A==">var audiotags="";var lid='1';function SetAudioTags(){if($('.dvMainBodyCLS h1').length>0){audiotags=audiotags+".dvMainBodyCLS h1,";}
# if($('.dvMainBodyCLS h2').length>0){audiotags=audiotags+".dvMainBodyCLS h2,";}
# if($('.dvMainBodyCLS .contentcol ul li a').length>0){audiotags=audiotags+".dvMainBodyCLS .contentcol ul li a,";}
# if($('.dvMainBodyCLS h3').length>0&&$('.exceprt-sec-text').length<=0){audiotags=audiotags+".dvMainBodyCLS h3,";}
# if($('.dvMainBodyCLS p').length>0&&$('.exceprt-sec-text').length<=0){audiotags=audiotags+".dvMainBodyCLS p,";}
# if($('.dvMainBodyCLS p strong').length>0){audiotags=audiotags+".dvMainBodyCLS p strong,";}
# if($('.dvMainBodyCLS h4').length>0){audiotags=audiotags+".dvMainBodyCLS h4,";}
# if($('.inner_post_content ul li').length>0&&$('.exceprt-sec-text').length<=0){audiotags=audiotags+".inner_post_content ul li,";}
# if($('.inner_post_content h5').length>0){audiotags=audiotags+".inner_post_content h5,";}
# if($('.inner_post_content table thead tr th').length>0){audiotags=audiotags+".inner_post_content table thead tr th,";}
# if($('.inner_post_content table tbody tr td').length>0){audiotags=audiotags+".inner_post_content table tbody tr td,";}
# if($('.inner_post_content ol li').length>0){audiotags=audiotags+".inner_post_content ol li,";}
# if($('.exceprt-sec-text').length>0){audiotags=audiotags+".exceprt-sec-text,";if($('.exceprt-sec-text ul li').length>0){audiotags=audiotags+".exceprt-sec-text ul li,";}
# if($('.exceprt-sec-text p').length>0){audiotags=audiotags+".exceprt-sec-text p,";}}
# if($('.dvMainBodyCLS h2 button').length>0){audiotags=audiotags+".dvMainBodyCLS h2 button,";}
# if($('.card-body').length>0){if($('.card-body ul li div h5').length>0){audiotags=audiotags+".card-body ul li div h5,";}
# if($('.card-body ul li').length>0){audiotags=audiotags+".card-body ul li,";}}
# audiotags=audiotags.replace(/,$/,'');}
# $(document).ready(function(){$('#audiopause').hide();SetAudioTags();$('#audioplay').click(function(){if(audiotags!=null&&audiotags!=""&&typeof audiotags!='undefined'){if(lid=='2'||lid=='3'){$(audiotags).articulate('ignore','img').articulate('setVoice','language','hi').articulate('speak');}
# else{$(audiotags).articulate('ignore','img').articulate('speak');}}
# $(this).hide();$('#audiopause').show();});$('#audiopause').click(function(){if(audiotags!=null&&audiotags!=""&&typeof audiotags!='undefined'){$(audiotags).articulate('stop');}
# $(this).hide();$('#audioplay').show();});});</script><script>$(document).ready(function(){if($('#capImg').length>0){let storedCaptchaSrc=removeQueryParams($('#capImg').attr('src'));$('#speak_captcha').on('click',function(){let img=new Image();img.crossOrigin="Anonymous";img.src=storedCaptchaSrc;img.onload=function(){Tesseract.recognize(img.src,'eng',{logger:m=>console.log(m),tessedit_char_whitelist:'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789',psm:6}).then(({data:{text}})=>{let cleanedText=text.replace(/[^a-zA-Z0-9]/g,'');if(cleanedText.length>0){speakCharactersWithCase(cleanedText);}else{console.log("Failed to read CAPTCHA correctly. Please try again.");}}).catch(err=>{console.error("OCR Failed:",err);console.log("Failed to extract text from CAPTCHA.");});};});}});function speakCharactersWithCase(text){let delay=700;text.split('').forEach((char,index)=>{setTimeout(()=>{let msgText=char;if(char.match(/[A-Z]/)){msgText="Uppercase "+char;}else if(char.match(/[a-z]/)){msgText="Lowercase "+char;}
# let msg=new SpeechSynthesisUtterance(msgText);msg.rate=0.8;window.speechSynthesis.speak(msg);},index*delay);});}</script><script nonce="FSBwwDG480WlsNU18kTc/A==">$(document).ready(function(){var width=$(window).width();if(width>=768){$('.floatBtns-fab').toggleClass("active");$('.floatBtns-fab .wrap').toggleClass("ani");$('.floatBtns').toggleClass("open");$('.img-fab.img').toggleClass("close");}});</script></body></head>
