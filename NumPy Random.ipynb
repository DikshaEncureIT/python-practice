# %%
from numpy import random

x = random.randint(100)
print(x)

x = random.rand(5)
print(x)
# Out:
# 24
# [0.58961639 0.19304681 0.24794834 0.2310778  0.31972245]

# %%
# Generate Random Array
x=random.randint(100, size=(5))
print(x)

x = random.randint(100, size=(5, 5))
print(x)

x = random.rand(5)

print(x)

x = random.choice([3, 5, 7, 9])

print(x)
# Out:
# [13 91  8 34 72]
# [[72 82 41 91 26]
#  [ 4 75 72  9  1]
#  [ 8  9 36 27 93]
#  [40 64 37 33 29]
#  [63 72 91 43 15]]
# [0.28516415 0.62346725 0.75897131 0.23674011 0.81125962]
# 9

# %%
x = random.choice([3, 5, 7, 9], size=(3, 5))

print(x)
# Out:
# [[5 7 5 5 9]
#  [9 5 3 3 9]
#  [5 3 9 5 3]]

# %%
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5))

print(x)
# Out:
# [[5 5 7 7 7]
#  [5 5 3 7 5]
#  [7 7 5 5 3]]

# %%
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.4, 0.2], size=(10))

print(x)
# Out:
# [7 7 7 5 9 5 7 9 7 9]

# %%
# Random Distribution
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.5, 0.1], size=(50))
print(x)
# Out:
# [5 7 7 9 7 7 5 7 7 7 7 3 5 5 3 7 3 7 7 9 7 7 7 9 7 7 5 5 3 7 7 9 3 5 9 7 5
#  7 7 5 9 7 7 5 7 7 7 7 7 7]

# %%
# return a 2-D array with 3 rows, each containing 5 values.
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5))
print(x)
# Out:
# [[5 7 3 7 5]
#  [7 5 5 7 5]
#  [7 7 5 5 7]]

# %%
# shuffle example
from numpy import random
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
random.shuffle(arr)
print(arr)
# Out:
# [3 2 1 4 5]

# %%
# permutation example
arr = np.array([1, 2, 3, 4, 5])
print(random.permutation(arr))
# Out:
# [1 5 3 2 4]

# %%
try:
    import seaborn as sns
    print("Seaborn is installed. Version:", sns.__version__)
except ImportError:
    print("Seaborn is NOT installed.")
# Out:
# Seaborn is installed. Version: 0.13.2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot([0, 1, 2, 4, 5])

plt.show()

# %%
sns.displot([0, 1, 2, 3, 4, 5], kind="kde")

plt.show()

# %%
sns.displot([0, 8, 2, 3, 4, 5], kind="ecdf")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 10, 115, 120, 125])
y = np.array([240, 250, 260, 2, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='PuBuGn')

plt.colorbar()

plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "#4CAF50")
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
# Normal distrubution

from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.normal(size=100),kind="kde")
plt.show()

# %%
# Binomial Distribution

x=random.binomial(n=5, p=0.5, size=5)
print(x)

sns.displot(random.binomial(n=10, p=0.5, size=1000))
plt.show()
# Out:
# [3 0 4 2 3]

# %%
# Difference Between Normal and Binomial Distribution

data = {
  "normal": random.normal(loc=50, scale=5, size=1000),
  "binomial": random.binomial(n=100, p=0.5, size=1000)
}

sns.displot(data, kind="kde")

plt.show()

# %%
# Poisson Distribution

sns.displot(random.poisson(lam=2, size=1000))
plt.show()

# %%
data = {
  "normal": random.normal(loc=50, scale=7, size=500),
  "poisson": random.poisson(lam=50, size=1000),
    "binomial": random.binomial(n=100, p=0.5, size=400)
}

sns.displot(data, kind="kde")

plt.show()

# %%
# Uniform Distribution
x = random.uniform(size=(2, 3))
print(x)

y=random.uniform(size=1000)
# print(y)
sns.displot(y, kind="kde")
plt.show()
# Out:
# [[0.88317311 0.81283044 0.18986457]
#  [0.79504059 0.75533433 0.85772405]]

# %%
# Logistic Distribution
x=random.logistic(loc=1, scale=2, size=(2, 3))
print(x)
sns.displot(random.logistic(size=1000), kind="kde")
plt.show()
# Out:
# [[-4.09692954  6.18419409 -2.07181435]
#  [ 1.12131807 -1.36612535  0.42320929]]

# %%
# Multinomial Distribution
x = random.multinomial(n=6, pvals=[1/6, 1/6, 1/6, 1/6, 1/6, 1/6])
print(x)
# Out:
# [3 0 1 2 0 0]

# %%
# Exponential Distribution
x = random.exponential(scale=2, size=(2, 3))
print(x)
sns.displot(random.exponential(size=1000))
plt.show()
# Out:
# [[0.91603534 0.26433547 2.49949123]
#  [4.02450365 1.58001913 0.87798094]]

# %%
# Chi Square Distribution
x = random.chisquare(df=2, size=(2, 3))
print(x)
sns.displot(random.chisquare(df=1, size=1000), kind="kde")
plt.show()
# Out:
# [[0.2686835  2.20267882 0.03808052]
#  [5.34922034 0.03196295 5.4455541 ]]

# %%
# Rayleigh Distribution
x = random.rayleigh(scale=2, size=(2, 3))
print(x)
sns.displot(random.rayleigh(size=1000), kind="kde")
plt.show()
# Out:
# [[1.21333585 2.67836211 4.07464594]
#  [4.10706404 3.38733623 1.53657622]]

# %%
# Pareto Distribution
x = random.pareto(a=2, size=(2, 3))
print(x)
sns.displot(random.pareto(a=2, size=1000))
plt.show()
# Out:
# [[0.55668028 0.77511662 0.38653505]
#  [0.69509736 0.11043508 1.95392841]]

# %%
# Zipf Distribution
x = random.zipf(a=2, size=(2, 3))
print(x)
x = random.zipf(a=2, size=1000)
sns.displot(x[x<10])
plt.show()
# Out:
# [[ 1  1  1]
#  [ 1 82  1]]
